# %%
# Imports and constants

import requests as rq
from bs4 import BeautifulSoup as soup
import pandas as pd
import time

bls_state_url = 'https://data.bls.gov/cgi-bin/surveymost?sm'

# %%
# Get response from bls main state unemployment site
bls_ro = rq.get(bls_state_url)
bls_ro
# Out:
# <Response [200]>

# %%
# Turn it into beautiful soup using BS4
ro_soup = soup(bls_ro.text, 'html.parser')
ro_soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="en">
# <head>
# <title>Top Picks (Most Requested Statistics) : U.S. Bureau of Labor Statistics</title>
# <!-- ****************************************** Begin META TAGS ********************************************* -->
# <!-- START include/global/head.stm -->
# <script id="_fed_an_ua_tag" src="https://dap.digitalgov.gov/Universal-Federated-Analytics-Min.js?agency=DOL&amp;subagency=BLS&amp;yt=true"></script>
# <script src="/javascripts/jquery-latest.js"></script>
# <script src="/javascripts/bls-latest.js"></script>
# <script src="/javascripts/jquery-tools.js"></script>
# <script src="/javascripts/jquery-migrate-1.2.1.min.js"></script>
# <link href="/assets/bootstrap/latest/bootstrap.min.css" rel="stylesheet"/>
# <script src="/assets/bootstrap/latest/popper.min.js"></script>
# <script src="/assets/bootstrap/latest/bootstrap.min.js"></script>
# <link href="/stylesheets/bls_combined.css" rel="stylesheet" type="text/css"/>
# <link href="/stylesheets/bls_content.css" rel="stylesheet" type="text/css"/>
# <link href="/stylesheets/bls_tables.css" rel="stylesheet" type="text/css"/>
# <link href="/stylesheets/jquery-tools.css" rel="stylesheet" type="text/css"/>
# <link href="/stylesheets/bls_nr.css" rel="stylesheet" type="text/css"/>
# <!--[if lt IE 9]>
# 		<link href="/stylesheets/ie8-styles.css" media="all" rel="Stylesheet" type="text/css">
# 	<![endif]-->
# <!--[if lt IE 8]>
# 		<link href="/stylesheets/ie7-styles.css" media="all" rel="Stylesheet" type="text/css">
# 	<![endif]-->
# <!--[if lt IE 7]>
# 		<link href="/stylesheets/ie6-styles.css" media="all" rel="Stylesheet" type="text/css">
# 		<style>
# 		body {
# 			behavior:url(/stylesheets/csshover2.htc);
# 		}
# 		</style>
# 	<![endif]-->
# <!--[if IE]>
# 		<style>
# 		body {
# 			font-size: expression(1 / (screen.deviceXDPI / 96) * 84 + '%');
# 		}
# 		</style>
# 	<![endif]-->
# <noscript>
# <link href="/stylesheets/bls_noscript.css" rel="stylesheet" type="text/css"/>
# </noscript>
# <!--  This means that the browser will (probably) render the width of the page at the width of its own screen. -->
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=Edge" http-equiv="x-ua-compatible">
# <meta content="https://www.bls.gov/images/bls_emblem_2016.png" property="og:image"/>
# <meta content="BLS Logo" property="og:image:alt"/>
# <meta content="index, follow" name="robots"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="Bureau of Labor Statistics" property="og:site_name"/>
# <style>
# 			td.gsc-table-cell-thumbnail{
# 			display:none !important;
# 			}
# 		</style>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180">
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png">
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png">
# <link href="/manifest.json" rel="manifest">
# <link color="#5bbad5" href="/safari-pinned-tab.svg" rel="mask-icon">
# <meta content="#ffffff" name="theme-color">
# <script>
#
# function tls_version() {
#   var tls = headerObj["x-ssl-protocol"];
#
#  if (tls === "tlsv1.0" || tls ==="tlsv1"){
# 	var tlsValue = bls_getCookie("TLS_Version");
# 	if (tlsValue === null || tlsValue === undefined || tlsValue === "") {
# 		bls_setCookie("TLS_Version",tls,365);
# 		$("body").prepend('<a id="tlsMessageTrigger" rel="#tlsMessage" style="display:none;"></a>');
# 		$("body").prepend('<div class="bls-chartdata-overlay" id="tlsMessage" style="max-width: 562px;"><div class="bls-overlay-heading"><a href="javascript:void(0);">close</a> or Esc Key</div><a class="close"></a><p style="padding: 15px; font-size:19px;"><img src="/images/icons/icon_lrg_special_notice.gif" style="vertical-align:top; display:inline-block; width:9%; left: -4px; position:relative;" /><strong style="display:inline-block; width:89%">Security Updates: New requirements to access BLS websites starting October 1, 2018</strong></p><p style="padding:0 15px 15px 15px; font-size: 14px; line-height: 1.6em;">Starting October 1st, you will no longer be able to access BLS websites using your current browser. BLS is updating its website security. To access our websites, you will need to have a browser with compatible security features. For more information, see: <a href="/bls/disable-transport-layer-security-1-0.htm">https://www.bls.gov/bls/disable-transport-layer-security-1-0.htm</a>.</p></div>');
# 		$("#tlsMessageTrigger[rel]").overlay({
# 			top:200,
# 			left:"center",
# 			onLoad:function(e){
# 				$("#tlsMessage .bls-overlay-heading a").click(function(){
# 					$("#tlsMessageTrigger[rel]").overlay().close();
# 				});
# 				$("#tlsMessage").css("left",(($(window).width()/2) - ($("#tlsMessage").width()/2)) + "px");
# 			},
# 			closeOnClick:false,
# 			mask: {
# 			color: '#000',
# 			loadSpeed: 200,
# 			opacity: 0.5,
# 			zIndex: 10000
# 			}
# 		});
# 		  $("#tlsMessageTrigger").click();
#
# 		}
# 	}
# }
#
#
#   var headerObj = {};
#   (function getHeader(){
# 	var req = new XMLHttpRequest();
# 	if(window.XDomainRequest){
# 		req.open('GET', document.location);
# 		req.onreadystatechange = function(){
# 			if(req.readyState != 4){return false;}
# 			if(req.status != 200){return false;}
# 			headersToObj(req.getAllResponseHeaders());
# 			return true;
# 		}
# 	  }else{
# 		req.open('HEAD', document.location, true);
# 		req.onload = function(e){
# 			if(req.readyState === 4)  {
# 			  if(req.status === 200) {
# 				  headersToObj(req.getAllResponseHeaders());
# 				}
# 			  }
# 		};
# 	}
# 	req.send(null);
#   })();
#
#   function headersToObj(headerStr){
# 	var headerStr = String(headerStr).toLowerCase().split("\r\n");
# 	for(index in headerStr){
# 		headerArr = headerStr[index].split(": ");
# 		if(headerArr[1]){headerObj[headerArr[0]] = headerArr[1];}
# 	}
#   }
#
#   Object.size = function(obj) {
# 	var size = 0, key;
# 	for (key in obj) {
# 		if (obj.hasOwnProperty(key)) size++;
# 	}
# 	return size;
#   };
#
#   var headerInterval = setInterval(function(){
# 	if(Object.size(headerObj)){
# 		clearInterval(headerInterval);
# 		tls_version();
# 	}
#   },500);
#
#
# </script>
# <!-- END include/global/head.stm -->
# <meta content="BLS" name="agency">
# <meta content="general" name="audience"><!-- ****************************************** End META TAGS *********************************************** -->
# </meta></meta></meta></link></link></link></link></link></meta></head>
# <body>
# <!-- OneColHeadBasic Begin -->
# <!-- Header Filename: /include/perl/surveymost_header.tt -->
# <!--no_index_start-->
# <!-- DOL BANNER BEGIN -->
# <!-- DOL BANNER START -->
# <header> <!-- Header is closed at the end of BLS banner -->
# <a class="skiplink" href="#startcontent">Skip to Content</a>
# <div id="usa-banner-wrapper">
# <div class="bootstrap" id="usa-banner">
# <div class="content">
# <div class="USA-flag-link">
# <img alt="U.S. flag" src="https://www.dol.gov/themes/opa_theme/img/flag-favicon-57.png"/>
# <p>An official website of the United States government
#
# 	<button aria-controls="usaBanner" aria-expanded="false" data-target="#usaBanner" data-toggle="collapse" type="button">Here is how you know <span class="oi" data-glyph="chevron-bottom"></span></button>
# </p>
# </div>
# <a class="dolHolder" href="https://www.dol.gov/" id="dolHolder" target="_blank"><img alt="Department of Labor Logo" src="https://www.dol.gov/themes/opa_theme/img/logo-primary.svg">  United States Department of Labor</img></a>
# </div>
# <div class="collapse" id="usaBanner">
# <div class="row">
# <div class="col-md-6">
# <img alt="Dot gov" src="https://www.dol.gov/themes/opa_theme/img/icon-dot-gov.svg"/>
# <p>
# <strong>The .gov means it's official.</strong>
# <br/> Federal government websites often end in .gov or .mil. Before sharing sensitive information,
# 			make sure you're on a federal government site.
# 		</p>
# </div>
# <div class="col-md-6">
# <img alt="Https" class="usa-banner-icon usa-media_block-img" src="https://www.dol.gov/themes/opa_theme/img/icon-https.svg"/>
# <p>
# <strong>The site is secure.</strong>
# <br/> The
# 			<strong>https://</strong> ensures that you are connecting to the official website and that any
# 			information you provide is encrypted and transmitted securely.
# 		</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- DOL BANNER END -->
# <!-- DOL BANNER END -->
# <!-- BLS BANNER BEGIN -->
# <div id="bls-banner-wrapper">
# <div id="top"></div>
# <div class="bootstrap">
# <div>
# <div class="row autowidth" id="bls-banner">
# <div class="col-sm-12 col-md-7" id="bls-banner-emblem">
# <a href="/home.htm">U.S. Bureau of Labor Statistics</a>
# </div>
# <div class="col-sm-12 col-md-5 d-none d-md-block" id="bls-banner-right">
# <div id="bls-banner-links"><span class="social-follow"><a aria-label="Follow Us on X, formerly referred to as Twitter" href="https://twitter.com/BLS_gov" target="_blank" title="Follow Us on X, formerly referred to as Twitter">Follow Us</a> </span><span class="social-follow-links">
# <!-- <img src="/images/icons/facebook.png"/>-->
# <a aria-label="Follow Us on X, formerly referred to as Twitter" href="https://twitter.com/BLS_gov" target="_blank"><img alt="Follow Us on X, formerly referred to as Twitter" src="/images/icons/twitter.png" style="margin-top:-10px;"/></a>
# <!--<img src="/images/icons/linkedin.png"/>-->
# </span> | <a href="/schedule/news_release/">Release Calendar</a> | <a aria-label="Blog page" href="/blog/">Blog</a></div>
# <div class="bls-banner-search" id="bls-banner-search1">
# <form action="/search/query" method="get">
# <label class="invisible" for="bls-banner-search-submit1">Search button</label>
# <input alt="BLS Search Submit" id="bls-banner-search-submit1" name="term" src="/images/buttons/search_button_blue_16.png" title="Submit" type="image"/>
# <label class="invisible" for="bls-banner-search-input1">Search:</label>
# <input id="bls-banner-search-input1" name="query" onclick="this.value=''; this.onclick = null;" title="Search Input" type="text" value="Search BLS.gov"/>
# </form>
# </div>
# </div>
# <div class="clearfloat"></div>
# </div>
# </div>
# </div>
# </div>
# </header> <!-- Header is opened at the begining of DOL banner --><!-- BLS BANNER END -->
# <!-- MAIN NAV BEGIN -->
# <div id="main-nav-wrapper">
# <div id="main-nav-container-autowidth">
# <div>
# <div class="bootstrap standard-width">
# <nav aria-label="top-level navigation menu" class="navbar navbar-expand-md">
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation menu" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon">Menu</span>
# </button>
# <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="nojs navbar-nav mr-auto">
# <li class="dropdownSearch"><div class="dropdown-search" id="bls-banner-search">
# <form action="/search/query" method="get">
# <label class="invisible" for="bls-banner-search-submit">Search button</label>
# <input alt="BLS Search Submit" id="bls-banner-search-submit" name="term" src="/images/buttons/search_button_blue_20.png" title="Submit" type="image"/>
# <label class="invisible" for="bls-banner-search-input">Search:</label>
# <input id="bls-banner-search-input" name="query" onclick="this.value=''; this.onclick = null;" title="Search Input" type="text" value="Search BLS.gov"/>
# </form>
# </div>
# <div class="bls-banner-links-mob"><span class="social-follow"><a aria-label="Follow Us on X, formerly referred to as Twitter" href="https://twitter.com/BLS_gov" target="_blank" title="Follow Us on X, formerly referred to as Twitter">Follow Us <img alt="Follow Us on X, formerly referred to as Twitter" src="/images/icons/twitter.png"/></a> </span>| <a href="/schedule/news_release/">Release Calendar</a> | <a aria-label="Blog page" href="/blog/">Blog</a></div>
# </li>
# <li class="nav-item dropdown"><a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="https://www.bls.gov/" id="navbarDropdown1" role="button">Home <span class="circle-arrow"></span></a>
# <div aria-labelledby="navbarDropdown1" class="dropdown-menu"><!-- ********************************************** Begin Home Tab LIST ****************************************** -->
# <!-- 1st column -->
# <div class="main-nav-submenu" id="submenu-home">
# <ul class="main-nav-submenu-inn">
# <li class="heading"><a aria-label="About BLS" href="/bls/about-bls.htm">About BLS</a></li>
# <li><a aria-label="BLS History" href="/bls/history/home.htm">History</a></li>
# <li><a aria-label="Our Leadership" href="/bls/senior_staff/home.htm">Our Leadership</a></li>
# <li><a aria-label="Budget and Performance" href="/bls/bls_budget_and_performance.htm">Budget and Performance</a></li>
# <li><a aria-label="Questions and Answers" href="/bls/faqs.htm">Questions and Answers</a></li>
# <li><a aria-label="A-Z Index" href="/bls/topicsaz.htm">A-Z Index</a></li>
# <li><a aria-label="Glossary" href="/bls/glossary.htm">Glossary</a></li>
# <li><a aria-label="Careers at BLS" href="/jobs/">Careers at BLS </a></li>
# <li><a aria-label="BLS Speakers Available" href="/bls/bls-speakers/">BLS Speakers Available</a></li>
# <li><a aria-label="Errata" href="/errata/">Errata</a></li>
# <li><a aria-label="Contact BLS" href="/bls/contact.htm">Contact BLS</a></li>
# </ul>
# <!-- 2nd column -->
# <ul class="main-nav-submenu-inn">
# <li class="heading"><a aria-label="Overview of BLS Statistics" href="/bls/overview.htm">Overview of BLS Statistics</a></li>
# <li><a aria-label="Guide to Programs &amp; Services" href="/information-guide/home.htm">Guide to Programs &amp; Services</a></li>
# <li><a aria-label="Demographics Data" href="/bls/demographics.htm">Demographics</a></li>
# <li><a aria-label="Statistics by Industries" href="/bls/industry.htm">Industries</a></li>
# <li><a aria-label="Statistics on Business Costs" href="/bls/business.htm">Business Costs</a></li>
# <li><a aria-label="Statistics by Occupations" href="/bls/occupation.htm">Occupations</a></li>
# <li><a aria-label="Statistics by Geography" href="/bls/geography.htm">Geography</a></li>
# </ul>
# <!-- 3rd column -->
# <ul class="main-nav-submenu-inn">
# <li class="heading"><a aria-label="Resources For" href="/audience/">Resources For</a></li>
# <li><a aria-label="Resources for Business Leaders" href="/audience/business.htm">Business Leaders</a></li>
# <li><a aria-label="Resources for Consumers" href="/audience/consumers.htm">Consumers</a></li>
# <li><a aria-label="Developers site" href="/audience/developers.htm">Developers</a></li>
# <li><a aria-label="Economists or Economic Analyst" href="/audience/economists.htm">Economists</a></li>
# <li><a aria-label="Resources for Financial Investors" href="/audience/investors.htm">Investors</a></li>
# <li><a aria-label="Resources for Jobseekers" href="/audience/jobseekers.htm">Jobseekers</a></li>
# <li><a aria-label="Media" href="/audience/media.htm">Media</a></li>
# <li><a aria-label="Resources for Public Policymakers" href="/audience/policy.htm">Public Policymakers</a></li>
# <li><a aria-label="Researcher" href="/audience/researcher.htm">Researcher</a></li>
# <li><a aria-label="Resources for Students &amp; Teachers" href="/audience/students.htm">Students &amp; Teachers</a></li>
# <li><a aria-label="Survey Respondents" href="/respondents/">Survey Respondents</a></li>
# </ul>
# </div>
# <!-- ***********************************************End Home Tab LIST ******************************************** -->
# </div>
# </li>
# <li class="nav-item dropdown"><a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="/bls/proghome.htm" id="navbarDropdown2" role="button">Subjects <span class="circle-arrow"></span></a>
# <div aria-labelledby="navbarDropdown2" class="dropdown-menu"><!-- ************************************* Begin SUBJECTS TAB list ****************************************** -->
# <!-- 1st column -->
# <div class="main-nav-submenu" id="submenu-programs">
# <ul class="main-nav-submenu-inn">
# <li class="heading"><a aria-label="Statistics on Inflation &amp; Prices" href="/bls/inflation.htm">Inflation &amp; Prices</a></li>
# <li><a aria-label="Consumer Price Index " href="/cpi/">Consumer Price Index</a></li>
# <li><a aria-label="Producer Price Indexes" href="/ppi/">Producer Price Indexes</a></li>
# <li><a aria-label="Import/Export Price Indexes" href="/mxp/">Import/Export Price Indexes</a></li>
# <li><a aria-label="Contract Escalation" href="/bls/escalation.htm">Contract Escalation</a></li>
# <li><a aria-label="Price Index Research" href="/pir/">Price Index Research</a></li>
# <li class="heading"><a aria-label="Statistics on Pay &amp; Benefits" href="/bls/wages.htm">Pay &amp; Benefits</a></li>
# <li><a aria-label="Employment Cost Index" href="/eci/">Employment Cost Index</a></li>
# <li><a aria-label="Employer Costs for Employee Compensation" href="/ecec/home.htm">Employer Costs for Employee Compensation</a></li>
# <li><a aria-label="Wage Data by Occupation" href="/oes/">Wage Data by Occupation</a></li>
# <li><a aria-label="Earnings by Demographics" href="/cps/earnings.htm#demographics">Earnings by Demographics</a></li>
# <li><a aria-label="Earnings by Industry" href="/ces/">Earnings by Industry</a></li>
# <li><a aria-label="County Wages" href="https://www.bls.gov/cew/">County Wages</a></li> <!--full path is needed since they have a folder on the data server-->
# <li><a aria-label="Employee Benefits Survey" href="/ebs/">Benefits</a></li>
# <li><a aria-label="Modeled Wage Estimates" href="/mwe/">Modeled Wage Estimates</a></li>
# <li><a aria-label="Compensation Research &amp; Program Development" href="/crp/">Compensation Research</a></li>
# <li><a aria-label="Strikes &amp; Lockouts" href="/wsp/">Strikes &amp; Lockouts </a></li>
# <li><a aria-label="Wage Records from Unemployment Insurance" href="/wrp/">Wage Records from Unemployment Insurance</a></li>
# <li class="heading"><a aria-label="Occupational Requirements Survey" href="/ors/">Occupational Requirements</a></li>
# </ul>
# <!-- 2nd column -->
# <ul class="main-nav-submenu-inn">
# <li class="heading"><a aria-label="Statistics on Unemployment" href="/bls/unemployment.htm">Unemployment</a></li>
# <li><a aria-label="National Unemployment Rate" href="/cps/">National Unemployment Rate </a></li>
# <li><a aria-label="State &amp; Local Unemployment Rates" href="/lau/">State &amp; Local Unemployment Rates </a></li>
# <li><a aria-label="Unemployment Research" href="/ers/">Unemployment Research</a></li>
# <li class="heading"><a aria-label="Statistics on Employment" href="/bls/employment.htm">Employment</a></li>
# <li><a aria-label="National Employment Statistics" href="/ces/">National Employment </a></li>
# <li><a aria-label="State &amp; Local Employment, Hours, and Earnings" href="/sae/">State &amp; Local Employment </a></li>
# <li><a aria-label="County Employment" href="https://www.bls.gov/cew/">County Employment </a></li> <!--full path is needed since they have a folder on the data server-->
# <li><a aria-label="Worker Characteristics" href="/cps/">Worker Characteristics </a></li>
# <li><a aria-label="American Indian Report" href="/air/">American Indian Report</a></li>
# <li><a aria-label="Employment Projections" href="/emp/">Employment Projections </a></li>
# <li><a aria-label="Job Openings &amp; Labor Turnover Survey" href="/jlt/">Job Openings &amp; Labor Turnover Survey </a></li>
# <li><a aria-label="Business Response Survey" href="/brs/">Business Response Survey</a></li>
# <li><a aria-label="Employment by Occupation" href="/oes/">Employment by Occupation </a></li>
# <li><a aria-label="Work Experience Over Time" href="/nls/">Work Experience Over Time </a></li>
# <li><a aria-label="Business Employment Dynamics" href="/bdm/">Business Employment Dynamics </a></li>
# <li><a aria-label="Foreign Direct Investment" href="/fdi/">Foreign Direct Investment </a></li>
# <li><a aria-label="Employment Research and Program Development" href="/ers/">Employment Research</a></li>
# <li class="heading"><a aria-label="Workplace Injuries, Illnesses, and Fatalities" href="/iif/">Workplace Injuries</a></li>
# </ul>
# <!-- 3rd column -->
# <ul class="main-nav-submenu-inn">
# <li class="heading"><a aria-label="Productivity Statistics" href="/bls/productivity.htm">Productivity</a></li>
# <li><a aria-label="Labor and Total Factor Productivity" href="/productivity/">Labor and Total Factor Productivity</a></li>
# <li><a aria-label="Productivity Research and Program Development" href="/dpr/">Productivity Research</a></li>
# <li class="heading"><a aria-label="Statistics on Spending &amp; Time Use" href="/bls/spending.htm">Spending &amp; Time Use</a></li>
# <li><a aria-label="Consumer Expenditures Surveys" href="/cex/">Consumer Expenditures </a></li>
# <li><a aria-label="How Americans Spend Time Survey" href="/tus/">How Americans Spend Time</a></li>
# <li class="heading"><a aria-label="International Data and Technical Cooperation" href="/bls/international.htm">International</a></li>
# <li><a aria-label="International Technical Cooperation" href="/itc/">International Technical Cooperation</a></li>
# <li><a aria-label="Import/Export Price Indexes" href="/mxp/">Import/Export Price Indexes</a></li>
# <li class="heading"><a aria-label="Geographic Information" href="/regions/">Geographic Information</a></li>
# <li><a aria-label="Northeast (Boston-New York) Information Office" href="/regions/northeast/">Northeast (Boston-New York)</a></li>
# <li><a aria-label="Mid-Atlantic (Philadelphia) Information Office" href="/regions/mid-atlantic/">Mid-Atlantic (Philadelphia)</a></li>
# <li><a aria-label="Southeast (Atlanta) Information Office" href="/regions/southeast/">Southeast (Atlanta)</a></li>
# <li><a aria-label="Midwest (Chicago) Information Office" href="/regions/midwest/">Midwest (Chicago)</a></li>
# <li><a aria-label="Southwest (Dallas) Information Office" href="/regions/southwest/">Southwest (Dallas)</a></li>
# <li><a aria-label="Mountain-Plains (Kansas City) Information Office" href="/regions/mountain-plains/">Mountain-Plains (Kansas City)</a></li>
# <li><a aria-label="West (San Francisco) Information Office" href="/regions/west/">West (San Francisco)</a></li>
# </ul>
# </div>
# <!-- **************************************End SUBJECT AREAS ******************************************** -->
# </div>
# </li>
# <li class="nav-item dropdown active"><a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="/data/" id="navbarDropdown3" role="button">Data Tools <span class="circle-arrow"></span></a>
# <div aria-labelledby="navbarDropdown3" class="dropdown-menu"><!-- ******************************************** Begin DATA TOOLS LIST ****************************************** -->
# <div class="main-nav-submenu" id="submenu-data">
# <ul class="main-nav-submenu-inn">
# <li class="heading"><a aria-label="Data Retrieval Tools Databases, Tables &amp; Calculators by Subject" href="/data/tools.htm">Data Retrieval Tools</a></li>
# <li><a aria-label="BLS Popular Series Top Picks" href="https://data.bls.gov/cgi-bin/surveymost?bls">BLS Popular Series</a></li>
# <li><a aria-label="Series Report" href="https://data.bls.gov/cgi-bin/srgate">Series Report</a></li>
# <li><a aria-label="Top Picks, One Screen, Multi-Screen, and Maps" href="/data/home.htm">Top Picks, One Screen, Multi-Screen, and Maps</a></li>
# <li><a aria-label="Data Finder" href="https://beta.bls.gov/dataQuery/search">Data Finder</a></li>
# <li><a aria-label="Public Data API Programming Interface" href="/developers/home.htm">Public Data API</a></li>
# </ul>
# <!-- 2nd column -->
# <ul class="main-nav-submenu-inn">
# <li class="heading"><a aria-label="Charts and Applications" href="/data/apps.htm">Charts and Applications</a></li>
# <li><a aria-label="Charts for Economic News Releases" href="/charts/home.htm">Charts for Economic News Releases</a></li>
# <li><a aria-label="CPI Inflation Calculator" href="/data/inflation_calculator.htm">CPI Inflation Calculator</a></li>
# <li><a aria-label="Injury and Illness Calculator" href="https://data.bls.gov/iirc/">Injury and Illness Calculator</a></li>
# <li><a aria-label="Pay Measure Comparison" href="https://data.bls.gov/apps/compensation-comparison-matrix/home.htm">Pay Measure Comparison</a></li>
# <li><a aria-label="Demographic Data Sources" href="https://data.bls.gov/apps/demographic-comparison-matrix/home.htm">Demographic Data Sources</a></li>
# <li><a aria-label="COVID-19 Economic Trends" href="https://data.bls.gov/apps/covid-dashboard/home.htm">COVID-19 Economic Trends</a></li>
# <li><a aria-label="Industry Productivity Viewer" href="https://data.bls.gov/apps/industry-productivity-viewer/home.htm">Industry Productivity Viewer</a></li>
# <li><a aria-label="Employment and Wages Data Viewer" href="https://data.bls.gov/cew/apps/data_views/data_views.htm#tab=Tables">Employment and Wages Data Viewer</a></li>
# <li><a aria-label="Industry Finder from the Quarterly Census of Employment and Wages" href="https://data.bls.gov/cew/apps/bls_naics/bls_naics_app.htm">Industry Finder from the Quarterly Census of Employment and Wages</a></li>
# </ul>
# <!-- 3rd column -->
# <ul class="main-nav-submenu-inn">
# <li class="heading"><a aria-label="Customized Tables" href="/data/tables.htm">Customized Tables</a></li>
# <li><a aria-label="U.S. Economy at a Glance" href="/eag/eag.us.htm">U.S. Economy at a Glance</a></li>
# <li><a aria-label="Regions, States &amp; Areas at a Glance" href="/eag/home.htm">Regions, States &amp; Areas at a Glance</a></li>
# <li><a aria-label="Industry at a Glance" href="/iag/home.htm">Industry at a Glance</a></li>
# <li><a aria-label="Text Files" href="https://download.bls.gov/pub/time.series/">Text Files</a></li>
# <li><a aria-label="Historical News Release Tables" href="/data/#historical-tables">News Release Tables</a></li>
# <li class="heading"><a aria-label="More Sources of Data" href="/bls/moredata.htm">More Sources of Data</a></li>
# <li><a aria-label="Bureau of Labor Statistics Restricted Data Access" href="/rda/home.htm">Restricted Data Access</a></li>
# <li><a aria-label="Discontinued Databases" href="/data/archived.htm">Discontinued Databases </a></li>
# <li><a aria-label="Questions &amp; Answers regarding Bureau of Labor Statistics website data retrieval tools" href="/help/hlpform1.htm">Questions &amp; Answers</a></li>
# <li><a aria-label="Special Notices" href="/help/notice.htm">Special Notices </a></li>
# </ul>
# </div>
# <!-- *********************************************End DATABASES and TOOLS LIST ******************************************** --></div>
# </li>
# <li class="nav-item dropdown"><a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="/opub/" id="navbarDropdown4" role="button">Publications <span class="circle-arrow"></span></a>
# <div aria-labelledby="navbarDropdown4" class="dropdown-menu"><!-- ********************************************** Begin PUBLICATIONS LIST ****************************************** -->
# <div class="main-nav-submenu" id="submenu-pubs">
# <ul class="main-nav-submenu-inn">
# <li class="heading"><a aria-label="Latest Publications" href="/opub/">Latest Publications</a></li>
# <li><a aria-label="The Economics Daily" href="/opub/ted/">The Economics Daily</a></li>
# <li><a aria-label="Monthly Labor Review" href="/opub/mlr/">Monthly Labor Review</a></li>
# <li><a aria-label="Beyond the Numbers" href="/opub/btn/">Beyond the Numbers</a></li>
# <li><a aria-label="Spotlight on Statistics" href="/spotlight/">Spotlight on Statistics</a></li>
# <li><a aria-label="Bureau of Labor Statistics Reports" href="/opub/reports">Reports</a></li>
# <li><a aria-label="Commissioner's Corner" href="/blog/">Commissioner's Corner</a></li>
# <li><a aria-label="Videos" href="/video/">Videos</a></li>
# <li><a aria-label="Career Outlook" href="/careeroutlook/">Career Outlook</a></li>
# </ul>
# <!-- 2nd column -->
# <ul class="main-nav-submenu-inn">
# <li><a aria-label="Occupational Outlook Handbook" href="/ooh/">Occupational Outlook Handbook</a></li>
# <li><a aria-label="Geographic Profile" href="/opub/geographic-profile/">Geographic Profile</a></li>
# <li><a aria-label="Handbook of Methods" href="/opub/hom/">Handbook of Methods</a></li>
# <li><a aria-label="Research Papers - Office of Survey Methods Research" href="/osmr/research-papers/">Research Papers</a></li>
# <li><a aria-label="Copyright Information" href="/opub/copyright-information.htm">Copyright Information</a></li>
# <li><a aria-label="Contact &amp; Help" href="/opub/opbinfo.htm">Contact &amp; Help </a></li>
# <li><a aria-label="Weekly Update" href="/opub/update.htm">Weekly Update</a></li>
# </ul>
# </div>
# <!-- ***********************************************End PUBLICATIONS LIST ******************************************** --> </div>
# </li>
# <li class="nav-item dropdown"><a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="/bls/newsrels.htm" id="navbarDropdown5" role="button">Economic Releases <span class="circle-arrow"></span></a>
# <div aria-labelledby="navbarDropdown5" class="dropdown-menu"><!-- ********************************************** Begin ECONOMIC RELEASES LIST ****************************************** -->
# <!-- 1st column -->
# <div class="main-nav-submenu" id="submenu-news">
# <ul class="main-nav-submenu-inn">
# <li class="heading"><a aria-label="Latest Releases" href="/bls/newsrels.htm#latest-releases">Latest Releases</a></li>
# <li class="heading"><a aria-label="Major Economic Indicators" href="/bls/newsrels.htm#major">Major Economic Indicators</a></li>
# <li class="heading"><a aria-label="Schedules for news Releases" href="/schedule/news_release/">Schedules for news Releases</a></li>
# <li><a aria-label="Release Calendar By Month" href="/schedule/">By Month</a></li>
# <li><a aria-label="Release Calendar By News Release" href="/schedule/schedule/by_prog/all_sched.htm">By News Release</a></li>
# <li><a aria-label="Release Calendar Current Year" href="/schedule/news_release/current_year.asp">Current Year</a></li>
# <li><a aria-label="Schedules for Selected Bureau of Labor Statistics Economic News Releases for Prior Years" href="/bls/archived_sched.htm">Prior Years</a></li>
# <li class="heading"><a aria-label="Archived News Releases" href="/bls/news-release/">Archived News Releases</a></li>
# </ul>
# <!-- 2nd column -->
# <ul class="main-nav-submenu-inn">
# <li class="heading"><a aria-label="Employment &amp; Unemployment" href="/bls/newsrels.htm#OEUS">Employment &amp; Unemployment</a></li>
# <li><a aria-label="Monthly" href="/bls/newsrels.htm#OEUS">Monthly</a></li>
# <li><a aria-label="Quarterly, annual, and other" href="/bls/newsrels.htm#OEUS">Quarterly, annual, and other</a></li>
# <li class="heading"><a aria-label="Inflation &amp; Prices" href="/bls/newsrels.htm#OPLC"> Inflation &amp; Prices</a></li>
# <li class="heading"><a aria-label="Pay &amp; Benefits &amp; Workplace Injuries" href="/bls/newsrels.htm#OCWC">Pay &amp; Benefits &amp; Workplace Injuries</a></li>
# <li class="heading"><a aria-label="Productivity &amp; Technology" href="/bls/newsrels.htm#OPT">Productivity &amp; Technology</a></li>
# <li class="heading"><a aria-label="Employment Projections" href="/bls/newsrels.htm#OEP">Employment Projections</a></li>
# <li class="heading"><a aria-label="Regional News Releases" href="/bls/newsrels.htm#NEWS">Regional News Releases</a></li>
# </ul>
# </div></div>
# </li>
# <li class="nav-item dropdown"><a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="/k12/" id="navbarDropdown6" role="button">Classroom <span class="circle-arrow"></span></a>
# <div aria-labelledby="navbarDropdown6" class="dropdown-menu"><!-- ********************************************** Begin Students Tab LIST ****************************************** -->
# <div class="main-nav-submenu" id="submenu-students">
# <ul class="main-nav-submenu-inn">
# <li class="heading"><a aria-label="K-12 Student &amp; Teacher Resources" href="/k12/">K-12 Student &amp; Teacher Resources</a></li>
# <li><a aria-label="Games &amp; Quizzes" href="/k12/games/">Games &amp; Quizzes</a></li>
# <li><a aria-label="Student's Desk" href="/k12/students/">Student's Desk</a></li>
# <li><a aria-label="Teacher's Desk" href="/k12/teachers/">Teacher's Desk</a></li>
# <li><a aria-label="Questions &amp; Answers" href="/k12/faq.htm">Questions &amp; Answers</a></li>
# </ul>
# </div>
# <!-- ***********************************************End Students Tab LIST ******************************************** --></div>
# </li>
# <li class="nav-item dropdown"><a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="/beta/" id="navbarDropdown7" role="button">Beta <span class="circle-arrow"></span></a>
# <div aria-labelledby="navbarDropdown7" class="dropdown-menu"><!-- ***********************************************Start BETA LIST ******************************************** -->
# <div class="main-nav-submenu" id="submenu-beta">
# <ul class="main-nav-submenu-inn">
# <li class="heading"><a aria-label="Redesigned News Releases" href="/beta/redesigned-news-releases.htm">Redesigned News Releases</a></li>
# </ul>
# </div>
# <!-- ***********************************************End BETA LIST ******************************************** --></div>
# </li>
# </ul>
# </div>
# </nav>
# </div>
# </div>
# <div class="clearfloat"></div>
# </div>
# </div>
# <!-- MAIN NAV END -->
# <!-- WRAPPER TOP BEGIN -->
# <div id="wrapper-basic" role="main">
# <!-- WRAPPER TOP END -->
# <!-- SUBDOMAIN TITLE TOP BEGIN -->
# <div id="subdomain-title">
# <span aria-level="1" id="subdomain-title-text" role="heading">
# <!-- SUBDOMAIN TITLE TOP END -->
# <!-- SUBDOMAIN TITLE BEGIN -->
# <!--no_index_end title-->
#
# Top Picks
#
# <!--no_index_start end title-->
# <!-- SUBDOMAIN TITLE END -->
# <!-- SUBDOMAIN TITLE MIDDLE BEGIN -->
# </span>
# <div class="article-tools-box-container">
# <div class="article-tools-box social-media" style="margin: 8px 0px 0px 4px;">
# <span class="social-media">
#             SHARE ON:
#            <a class="share_facebook" href="javascript:void(0);"><img alt="share on facebook" src="/images/icons/facebook.png" title="Facebook"/></a>
# <a class="share_twitter" href="javascript:void(0);"><img alt="share on twitter" src="/images/icons/twitter.png" title="Twitter"/></a>
# <a class="share_linkedin" href="javascript:void(0);"><img alt="share on linkedin" src="/images/icons/linkedin.png" title="LinkedIn"/></a>
# <!--<a href="javascript:void(0);" class="share_googleplus"><img src="/images/icons/google.png" title="Google Plus" /></a>-->
# </span>
# </div>
# </div>
# <!-- SUBDOMAIN TITLE MIDDLE END -->
# <div class="article-tools-box"><a class="thickbox" href="#TB_inline?height=400&amp;width=500&amp;inlineId=survey_links">OTHER SURVEYS <img alt="Survey Links" src="/images/icons/icon_small_link.gif"/></a></div>
# <div id="survey_links" style="display: none;">
# <h2>Other Surveys</h2>
# <ul>
# <li><a href="/data/">OTHER SURVEYS</a></li>
# <li><a href="/data/#employment">EMPLOYMENT &amp; UNEMPLOYMENT</a>
# <ul>
# <li><a href="/cgi-bin/surveymost?lf">Labor Force Statistics (SIC)</a></li>
# <li><a href="/cgi-bin/surveymost?ce">National Employment, Hours, and Earnings</a></li>
# <li><a href="/cgi-bin/surveymost?sm">State and Area Employment, Hours, and Earnings</a></li>
# <li><a href="/cgi-bin/surveymost?en">Quarterly Census of Employment and Wages</a></li>
# <li><a href="/cgi-bin/surveymost?bd">Business Employment Dynamics</a></li>
# <li><a href="/cgi-bin/surveymost?la">Local Area Unemployment Statistics</a></li>
# <li><a href="/cgi-bin/surveymost?ml">Mass Layoff Statistics</a></li>
# <li><a href="/cgi-bin/surveymost?jt">Job Openings and Labor Turnover Survey</a></li>
# <li><a href="/cgi-bin/surveymost?gg">Green Goods and Services</a></li>
# <li><a href="/oes/">Occupational Employment and Wage Statistics</a></li>
# <li><a href="/cgi-bin/surveymost?fm">Marital and Family Labor Force Statistics</a></li>
# </ul>
# </li>
# <li><a href="/data/#prices">PRICES &amp; LIVING CONDITIONS</a>
# <ul>
# <li><a href="/cgi-bin/surveymost?cu">Consumer Price Indexes (CPI)</a>
# <ul>
# <li><a href="/cgi-bin/surveymost?ap">Average Price Data</a></li>
# <li><a href="/cgi-bin/surveymost?cu">All Urban Consumers </a></li>
# <li><a href="/cgi-bin/surveymost?cw">Urban Wage Earners and Clerical Workers</a></li>
# <li><a href="/cgi-bin/surveymost?mu">All Urban Consumers (Old)</a></li>
# <li><a href="/cgi-bin/surveymost?mw">Urban Wage Earners and Clerical Workers (Old)</a></li>
# <li><a href="/cgi-bin/surveymost?li">Department Store Inventory Price Index</a></li>
# <li><a href="/cgi-bin/surveymost?su">Chained CPI-All Urban Consumers</a></li>
# </ul>
# </li>
# <li><a href="/cgi-bin/surveymost?wp">Producer Price Indexes (PPI)</a>
# <ul>
# <li><a href="/cgi-bin/surveymost?pc">Industry Data</a></li>
# <li><a href="/cgi-bin/surveymost?nd">Producer Price Index Industry Data - Discontinued Series (NAICS basis)</a></li>
# <li><a href="/cgi-bin/surveymost?pd">Producer Price Index Industry Data - Discontinued (SIC basis)</a></li>
# <li><a href="/cgi-bin/surveymost?wp">Commodity Data</a></li>
# <li><a href="/cgi-bin/surveymost?wd">Commodity Data - Discontinued Series</a></li>
# </ul>
# </li>
# <li><a href="/cgi-bin/surveymost?ei">Import/Export Price Indexes </a></li>
# <li><a href="/cgi-bin/surveymost?cx">Consumer Expenditure Survey</a></li>
# </ul>
# </li>
# <li><a href="/data/#wages">COMPENSATION &amp; WORKING CONDITIONS</a>
# <ul>
# <li><a href="/cgi-bin/surveymost?wm">Modeled Wage Estimates</a></li>
# <li><a href="/cgi-bin/surveymost?nb">National Compensation Survey - Benefits</a></li>
# <li><a href="/cgi-bin/surveymost?ws">Work Stoppage Data</a></li>
# <li><a href="/cgi-bin/surveymost?eb">Employee Benefits Survey</a></li>
# <li><a href="/cgi-bin/surveymost?ci">Employment Cost Index (NAICS)</a></li>
# <li><a href="/cgi-bin/surveymost?ec">Employment Cost Index (SIC) </a></li>
# <li><a href="/cgi-bin/surveymost?cm">Employer Cost for Employee Compensation </a></li>
# <li><a href="/gqt/servlet/InitialPage">Occupational Injuries and Illnesses Profiles</a></li>
# <ul>
# <li><a href="/cgi-bin/surveymost?cb">Biennial Nonfatal Case and Demographic numbers and rates: selected characteristics</a></li>
# <li><a href="/cgi-bin/surveymost?ch">Nonfatal cases involving days away from work: selected characteristics (2003 - 2010)</a></li>
# <li><a href="/cgi-bin/surveymost?is">Occupational injuries and illnesses: industry data (2014 forward)</a></li>
# <li><a href="/cgi-bin/surveymost?ii">Occupational injuries and illnesses: industry data (2003 - 2013)</a></li>
# <li><a href="/cgi-bin/surveymost?fw">Census of Fatal Occupational Injuries (2011 forward)</a></li>
# <li><a href="/cgi-bin/surveymost?fi">Census of Fatal Occupational Injuries (2003 - 2010)</a></li>
# </ul>
# <li><a href="/cgi-bin/surveymost?or">Occupational Requirements Survey</a></li>
# </ul>
# </li>
# <li><a href="/data/#productivity">PRODUCTIVITY &amp; TECHNOLOGY</a>
# <ul>
# <li><a href="/cgi-bin/surveymost?pr">Major Sector Productivity and Costs</a></li>
# <li><a href="/cgi-bin/surveymost?mp">Major Sector Total Factor Productivity</a></li>
# <li><a href="/cgi-bin/surveymost?ip">Industry Productivity</a></li>
# <li><a href="/cgi-bin/surveymost?in">Foreign Labor Statistics</a></li>
# </ul>
# </li>
# <li><a href="/data/#spending">SPENDING &amp; TIME USE</a>
# <ul>
# <li><a href="/cgi-bin/surveymost?tu">American Time Use Survey</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <!-- SUBDOMAIN TITLE BOTTOM BEGIN -->
# </div> <!-- End Subdomain Title Div -->
# <div id="subdomain-title-border"></div>
# <!-- SUBDOMAIN TITLE BOTTOM END -->
# <!-- 1COL LAYOUT COL1 BEGIN -->
# <div class="clearfloat" id="startcontent"></div>
# <div class="main-content" id="main-content-full-width">
# <div class="verdana md" id="bodytext">
# <!-- 1COL LAYOUT COL1 END -->
# <!--no_index_end-->
# <!-- MAIN CONTENT BEGIN -->
# <!-- ****************************************** END HEADER ************************************************ -->
# <ul>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+01">Alabama</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+02">Alaska</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+04">Arizona</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+05">Arkansas</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+06">California</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+08">Colorado</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+09">Connecticut</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+10">Delaware</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+11">District Of Columbia</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+12">Florida</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+13">Georgia</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+15">Hawaii</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+16">Idaho</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+17">Illinois</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+18">Indiana</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+19">Iowa</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+20">Kansas</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+21">Kentucky</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+22">Louisiana</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+23">Maine</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+24">Maryland</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+25">Massachusetts</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+26">Michigan</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+27">Minnesota</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+28">Mississippi</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+29">Missouri</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+30">Montana</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+31">Nebraska</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+32">Nevada</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+33">New Hampshire</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+34">New Jersey</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+35">New Mexico</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+36">New York</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+37">North Carolina</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+38">North Dakota</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+39">Ohio</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+40">Oklahoma</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+41">Oregon</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+42">Pennsylvania</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+72">Puerto Rico</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+44">Rhode Island</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+45">South Carolina</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+46">South Dakota</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+47">Tennessee</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+48">Texas</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+49">Utah</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+50">Vermont</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+51">Virginia</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+78">Virgin Islands</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+53">Washington</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+54">West Virginia</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+55">Wisconsin</a>
# <li><a href="https://data.bls.gov/cgi-bin/surveymost?sm+56">Wyoming</a>
# </li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></li></ul>
# <hr/>
# <!-- Start of hidden variables -->
# <input name="survey" size="0" type="hidden" value="sm"/>
# <!--  This is the beginning of the format hidden variables -->
# <input name="format" size="0" type="hidden" value=""/>
# <input name="html_tables" size="0" type="hidden" value=""/>
# <input name="delimiter" size="0" type="hidden" value=""/>
# <input name="catalog" size="0" type="hidden" value=""/>
# <input name="print_line_length" size="0" type="hidden" value=""/>
# <input name="lines_per_page" size="0" type="hidden" value=""/>
# <input name="row_stub_key" size="0" type="hidden" value=""/>
# <input name="year" size="0" type="hidden" value=""/>
# <input name="date" size="0" type="hidden" value=""/>
# <input name="net_change_start" size="0" type="hidden" value=""/>
# <input name="net_change_end" size="0" type="hidden" value=""/>
# <input name="percent_change_start" size="0" type="hidden" value=""/>
# <input name="percent_change_end" size="0" type="hidden" value=""/>
# <!-- End of format hidden variables -->
# <!-- End of hidden variables -->
# <!-- MAIN CONTENT END -->
# <!--no_index_start-->
# <!-- 2COL LAYOUT COL2 BEGIN -->
# </div>
# </div>
# <div class="clearfloat"></div>
# <!-- 2COL LAYOUT COL2 END -->
# <!-- QUICK LINKS BEGIN -->
# <!-- -->
# <!-- QUICK LINKS END -->
# <!-- WRAPPER BOTTOM BEGIN -->
# </div><!-- close id="wrapper-basic" -->
# <!-- WRAPPER BOTTOM END -->
# <!-- FOOTER LEFT BEGIN -->
# <footer>
# <!-- Footer Nav Menu-->
# <div class="footerNav">
# <ul class="footerNavInner">
# <li class="footerNavItem"><a href="https://www.bls.gov/">Home</a></li>
# <li class="footerNavItem"><a href="/bls/proghome.htm">Subjects</a></li>
# <li class="footerNavItem"><a href="/data/">Data Tools</a></li>
# <li class="footerNavItem"><a href="/opub/">Publications</a></li>
# <li class="footerNavItem"><a href="/bls/newsrels.htm">Economic Releases</a></li>
# <li class="footerNavItem"><a href="/k12/">Classroom</a></li>
# <li class="footerNavItem"><a href="/beta/">Beta</a></li>
# </ul>
# </div>
# <!-- Footer Nav Menu-->
# <script>/*<![CDATA[*/(function(){var sz = document.createElement('script'); sz.type = 'text/javascript'; sz.async = true;sz.src = '//siteimproveanalytics.com/js/siteanalyze_6032860.js';var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sz, s);})();/*]]>*/</script>
# <script src="/javascripts/touchpointsForms.js"></script>
# <link href="/stylesheets/touchpointsForms.css" rel="stylesheet" type="text/css"/>
# <div id="footer-primary-wrapper">
# <div class="bootstrap standard-width">
# <div class="row" id="footer-container">
# <div class="col-xs-12 col-sm-12 col-md-4 col-lg-4" id="footer-links-container">
# <div class="bls-lftside-holder">
# <div class="bls-logo-footer">
# <img alt="U.S. Bureau of Labor Statistics Logo " class="responsiveImg" src="/images/bls_emblem_trans.png"><div class="d-none d-md-block clearfloat"><br/><br/></div>
# </img></div>
# <div class="address-contact-footer"> <!-- FOOTER LEFT END -->
# <address class="footer-address">
# <strong>U.S. Bureau of Labor Statistics</strong>
# <span>Division of Current Employment Statistics</span>
# <span>PSB Suite 4860</span>
# <span>2 Massachusetts Avenue NE</span>
# <span>Washington, DC 20212-0001</span>
# </address>
# <!-- FOOTER CENTER BEGIN -->
# <!-- FOOTER CENTER END -->
# <span class="footer-contact">
# <a aria-label="Telephone: 1-202-691-6559" class="number" href="tel:12026916559">
# <span>Telephone:</span><span> 1-202-691-6559 </span>
# </a>
# <a aria-label="www.bls.gov/SAE" href="/sae/home.htm">www.bls.gov/SAE</a>
# <a aria-label="Contact SAE" href="/forms/sae.htm">Contact SAE</a>
# </span>
# <!-- FOOTER RIGHT BEGIN -->
# </div>
# </div>
# </div>
# <div class="row col-xs-12 col-sm-12 col-md-8 col-lg-8" id="quicklinks">
# <div class="col-xs-6 col-sm-6 col-md-6 col-lg-5">
# <strong>resources</strong>
# <a aria-controls="quicklinksli5" aria-expanded="false" aria-label="resources Sub Menu" class="d-sm-none" data-toggle="collapse" href="#quicklinksli5" role="button"></a>
# <div class="collapse" id="quicklinksli5">
# <ul class="d-sm-block">
# <li><a aria-label="Office of Inspector General (OIG) website" href="https://www.oig.dol.gov/">Inspector General (OIG)</a></li>
# <li><a aria-label="Budget and Performance" href="/bls/bls_budget_and_performance.htm">Budget and Performance</a></li>
# <li><a aria-label="Department of Labor Grants" href="https://www.dol.gov/grants">Department of Labor Grants</a></li>
# <li><a aria-label="No Fear Act" href="/bls/no_fear_act.htm">No Fear Act</a></li>
# <li><a aria-label="USA.gov website" href="https://www.usa.gov/">USA.gov</a></li>
# <li><a aria-label="Register to vote at Vote.gov" href="https://www.vote.gov/" title="Public and private decision making about worker rights and benefits depend on you exercising your fundamental right. Register to vote at Vote.gov!">Vote.gov</a></li>
# </ul>
# </div>
# </div>
# <div class="col-xs-6 col-sm-6 col-md-6 col-lg-5">
# <strong>about the site</strong>
# <a aria-controls="quicklinksli6" aria-expanded="false" aria-label="about this site Sub Menu" class="d-sm-none" data-toggle="collapse" href="#quicklinksli6" role="button"></a>
# <div class="collapse" id="quicklinksli6">
# <ul class="d-sm-block">
# <li><a aria-label="Sitemap" href="/bls/sitemap.htm">Sitemap</a></li>
# <li><a aria-label="Freedom of Information Act" href="/bls/blsfoia.htm">Freedom of Information Act</a></li>
# <li><a aria-label="Privacy and Security Statement" href="/bls/pss.htm">Privacy and Security Statement</a></li>
# <li><a aria-label="Disclaimers" href="/bls/disclaimer.htm">Disclaimers</a></li>
# <li><a aria-label="Linking and Copyright Information" href="/bls/linksite.htm">Linking and Copyright Info</a></li>
# <li><a aria-label="Important Website Notices" href="/bls/website-policies.htm">Important Website Notices</a></li>
# <li><a aria-label="Help and Tutorials" href="/help/">Help and Tutorials</a></li>
# <li><a aria-label="Language Services" href="/bls/babel.htm">Babel Notice: accessing language services</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="footer-secondary-wrapper">
# <div class="bootstrap standard-width">
# <div>
# <span>Connect With BLS</span>
# <div class="social-media-icons">
# <a class="social-media-icon" href="https://twitter.com/BLS_gov" rel="noopener noreferrer" target="_blank" title="Connect with BLS on X, formerly referred to as Twitter">
# <!--?xml version="1.0" encoding="utf-8"?-->
# <svg aria-hidden="true" class="svg-inline--fa fa-twitter fa-w-16" data-icon="twitter" data-prefix="fab" viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg"><path d="M389.2 48h70.6L305.6 224.2 487 464H345L233.7 318.6 106.5 464H35.8L200.7 275.5 26.8 48H172.4L272.9 180.9 389.2 48zM364.4 421.8h39.1L151.1 88h-42L364.4 421.8z" fill="currentColor"></path></svg>
# <span class="sr-only">Twitter</span>
# </a>
# <a class="social-media-icon" href="https://www.youtube.com/channel/UCijn3WBpHtx4AvSya7NER9Q" rel="noopener noreferrer" target="_blank" title="BLS Youtube">
# <!--?xml version="1.0" encoding="utf-8"?-->
# <svg aria-hidden="true" class="svg-inline--fa fa-youtube fa-w-18" data-icon="youtube" data-prefix="fab" viewbox="0 0 576 512" xmlns="http://www.w3.org/2000/svg"><path d="M549.655 124.083c-6.281-23.65-24.787-42.276-48.284-48.597C458.781 64 288 64 288 64S117.22 64 74.629 75.486c-23.497 6.322-42.003 24.947-48.284 48.597-11.412 42.867-11.412 132.305-11.412 132.305s0 89.438 11.412 132.305c6.281 23.65 24.787 41.5 48.284 47.821C117.22 448 288 448 288 448s170.78 0 213.371-11.486c23.497-6.321 42.003-24.171 48.284-47.821 11.412-42.867 11.412-132.305 11.412-132.305s0-89.438-11.412-132.305zm-317.51 213.508V175.185l142.739 81.205-142.739 81.201z" fill="currentColor"></path></svg>
# <span class="sr-only">Youtube</span>
# </a>
# <a class="social-media-icon" href="javascript:window.open('https://public.govdelivery.com/accounts/USDOLBLS/subscriber/new ','Popup','width=800,height=500,toolbar=no,scrollbars=yes,resizable=yes'); void('');" id="email" onclick="window.status='Subscribe'; return true" onmouseout="window.status=''; return true" onmouseover="window.status='Subscribe'; return true" title="Subscribe to BLS E-mail Updates">
# <!--?xml version="1.0" encoding="utf-8"?-->
# <svg aria-hidden="true" class="svg-inline--fa fa-envelope fa-w-16" data-icon="envelope" data-prefix="fas" focusable="false" viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg"><path d="M502.3 190.8c3.9-3.1 9.7-.2 9.7 4.7V400c0 26.5-21.5 48-48 48H48c-26.5 0-48-21.5-48-48V195.6c0-5 5.7-7.8 9.7-4.7 22.4 17.4 52.1 39.5 154.1 113.6 21.1 15.4 56.7 47.8 92.2 47.6 35.7.3 72-32.8 92.3-47.6 102-74.1 131.6-96.3 154-113.7zM256 320c23.2.4 56.6-29.2 73.4-41.4 132.7-96.3 142.8-104.7 173.4-128.7 5.8-4.5 9.2-11.5 9.2-18.9v-19c0-26.5-21.5-48-48-48H48C21.5 64 0 85.5 0 112v19c0 7.4 3.4 14.3 9.2 18.9 30.6 23.9 40.7 32.4 173.4 128.7 16.8 12.2 50.2 41.8 73.4 41.4z" fill="currentColor"></path></svg>
# <span class="sr-only">Email</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </footer><!-- FOOTER RIGHT END -->
# <!--no_index_end-->
# <!-- ****************************************** END FOOTER ************************************************ -->
# </body></html>

# %%
# Select only the tags containing links and names of states
state_links = ro_soup.css.select('a[href^="https://data.bls.gov/cgi-bin/surveymost?"]')
state_links
# Out:
# [<a aria-label="BLS Popular Series Top Picks" href="https://data.bls.gov/cgi-bin/surveymost?bls">BLS Popular Series</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+01">Alabama</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+02">Alaska</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+04">Arizona</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+05">Arkansas</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+06">California</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+08">Colorado</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+09">Connecticut</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+10">Delaware</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+11">District Of Columbia</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+12">Florida</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+13">Georgia</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+15">Hawaii</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+16">Idaho</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+17">Illinois</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+18">Indiana</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+19">Iowa</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+20">Kansas</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+21">Kentucky</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+22">Louisiana</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+23">Maine</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+24">Maryland</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+25">Massachusetts</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+26">Michigan</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+27">Minnesota</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+28">Mississippi</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+29">Missouri</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+30">Montana</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+31">Nebraska</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+32">Nevada</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+33">New Hampshire</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+34">New Jersey</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+35">New Mexico</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+36">New York</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+37">North Carolina</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+38">North Dakota</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+39">Ohio</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+40">Oklahoma</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+41">Oregon</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+42">Pennsylvania</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+72">Puerto Rico</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+44">Rhode Island</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+45">South Carolina</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+46">South Dakota</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+47">Tennessee</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+48">Texas</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+49">Utah</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+50">Vermont</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+51">Virginia</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+78">Virgin Islands</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+53">Washington</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+54">West Virginia</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+55">Wisconsin</a>,
#  <a href="https://data.bls.gov/cgi-bin/surveymost?sm+56">Wyoming</a>]

# %%
# List comprehension to make a list of links next to their respective states
state_link_list = [(state_links[i].get('href'), state_links[i].get_text()) for i in range(len(state_links))][1:]

# %%
# Define web-scraper
def state_scraper(state_link_list):

    final_df = pd.DataFrame([])

    for link in range(len(state_link_list)):

        # Response from link
        print(f'Initializing "get" request for {state_link_list[link][1]} ')
        state_ro = rq.get(state_link_list[link][0]) 
        print(f'State Link for {state_link_list[link][1]} Acquired')

        # Soup
        state_soup = soup(state_ro.text, 'html.parser')

        # Find serials and survey names
        state_serial_and_id = state_soup.find_all('dt')[0].get_text()

        # Split into list
        state_serial_and_id = state_serial_and_id.split('\n')[1:-1]

        # Turn into DataFrame, split by '-'
        df = pd.DataFrame([item.split(' - ') for item in state_serial_and_id], columns=['series', 'seriesID'])

        # Take state name from series column and put it in its own column
        df['state'] = df['series'].str[0:(df['series'].str.find(',').astype(int)[0])]
        df['series'] = df['series'].str[(df['series'].str.find(', ').astype(int)[0]+2):]

        # Add a new column that applies 't' if seasonally adjusted, 'f' if not
        df['is_adjusted'] = df['series'].str.lower().apply(lambda x: False if 'Not Seasonally Adjusted' in x else True)

        # Append to final DataFrame
        final_df = pd.concat([final_df, df], ignore_index= True)

        # Be nice to BLS
        print(f'{state_link_list[link][1]} data added to DataFrame')
        print('Sleeping for 2 seconds')
        time.sleep(2)
        

    final_df['survey'] = 'CES'
    return final_df

# %%
# Run it

result = state_scraper(state_link_list)
# Out:
# Initializing "get" request for Alabama
# State Link for Alabama Acquired
# Alabama data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Alaska
# State Link for Alaska Acquired
# Alaska data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Arizona
# State Link for Arizona Acquired
# Arizona data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Arkansas
# State Link for Arkansas Acquired
# Arkansas data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for California
# State Link for California Acquired
# California data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Colorado
# State Link for Colorado Acquired
# Colorado data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Connecticut
# State Link for Connecticut Acquired
# Connecticut data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Delaware
# State Link for Delaware Acquired
# Delaware data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for District Of Columbia
# State Link for District Of Columbia Acquired
# District Of Columbia data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Florida
# State Link for Florida Acquired
# Florida data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Georgia
# State Link for Georgia Acquired
# Georgia data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Hawaii
# State Link for Hawaii Acquired
# Hawaii data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Idaho
# State Link for Idaho Acquired
# Idaho data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Illinois
# State Link for Illinois Acquired
# Illinois data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Indiana
# State Link for Indiana Acquired
# Indiana data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Iowa
# State Link for Iowa Acquired
# Iowa data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Kansas
# State Link for Kansas Acquired
# Kansas data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Kentucky
# State Link for Kentucky Acquired
# Kentucky data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Louisiana
# State Link for Louisiana Acquired
# Louisiana data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Maine
# State Link for Maine Acquired
# Maine data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Maryland
# State Link for Maryland Acquired
# Maryland data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Massachusetts
# State Link for Massachusetts Acquired
# Massachusetts data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Michigan
# State Link for Michigan Acquired
# Michigan data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Minnesota
# State Link for Minnesota Acquired
# Minnesota data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Mississippi
# State Link for Mississippi Acquired
# Mississippi data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Missouri
# State Link for Missouri Acquired
# Missouri data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Montana
# State Link for Montana Acquired
# Montana data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Nebraska
# State Link for Nebraska Acquired
# Nebraska data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Nevada
# State Link for Nevada Acquired
# Nevada data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for New Hampshire
# State Link for New Hampshire Acquired
# New Hampshire data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for New Jersey
# State Link for New Jersey Acquired
# New Jersey data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for New Mexico
# State Link for New Mexico Acquired
# New Mexico data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for New York
# State Link for New York Acquired
# New York data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for North Carolina
# State Link for North Carolina Acquired
# North Carolina data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for North Dakota
# State Link for North Dakota Acquired
# North Dakota data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Ohio
# State Link for Ohio Acquired
# Ohio data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Oklahoma
# State Link for Oklahoma Acquired
# Oklahoma data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Oregon
# State Link for Oregon Acquired
# Oregon data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Pennsylvania
# State Link for Pennsylvania Acquired
# Pennsylvania data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Puerto Rico
# State Link for Puerto Rico Acquired
# Puerto Rico data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Rhode Island
# State Link for Rhode Island Acquired
# Rhode Island data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for South Carolina
# State Link for South Carolina Acquired
# South Carolina data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for South Dakota
# State Link for South Dakota Acquired
# South Dakota data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Tennessee
# State Link for Tennessee Acquired
# Tennessee data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Texas
# State Link for Texas Acquired
# Texas data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Utah
# State Link for Utah Acquired
# Utah data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Vermont
# State Link for Vermont Acquired
# Vermont data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Virginia
# State Link for Virginia Acquired
# Virginia data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Virgin Islands
# State Link for Virgin Islands Acquired
# Virgin Islands data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Washington
# State Link for Washington Acquired
# Washington data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for West Virginia
# State Link for West Virginia Acquired
# West Virginia data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Wisconsin
# State Link for Wisconsin Acquired
# Wisconsin data added to DataFrame
# Sleeping for 2 seconds
# Initializing "get" request for Wyoming
# State Link for Wyoming Acquired
# Wyoming data added to DataFrame
# Sleeping for 2 seconds

# %%
# Save to CSV
result.to_csv('state_series_dimension.csv')
